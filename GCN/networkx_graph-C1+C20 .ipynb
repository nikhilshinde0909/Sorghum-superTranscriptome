# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import networkx as nx
from pyvis.network import Network

# %%
data=pd.read_csv('C1+C20_NAC_slice.csv')

# %%
data
# Out:
#                    gene_ID Target   TF_gene_ID     TF_Family  \
# 0              MSTRG.40024  NAC-3  MSTRG.32973    A20-like-1
# 1    SbiBTX642.01G041300.1  NAC-7  MSTRG.25293    A20-like-3
# 2              MSTRG.27651  NAC-1  MSTRG.44365  AP2-EREBP-14
# 3              MSTRG.41286  NAC-8  MSTRG.11921  AP2-EREBP-15
# 4              MSTRG.27651  NAC-1   MSTRG.8359  AP2-EREBP-17
# ..                     ...    ...          ...           ...
# 461            MSTRG.26238  NAC-2  MSTRG.11249   WD40-like-8
# 462            MSTRG.43202  NAC-6  MSTRG.11249   WD40-like-8
# 463            MSTRG.41286  NAC-8  MSTRG.36048        WRKY-3
# 464            MSTRG.43202  NAC-6   MSTRG.3971        bHLH-2
# 465            MSTRG.43202  NAC-6  MSTRG.19683        bZIP-1
#
#     coexpression_type  PCC_under_C1  PCC_under_C2
# 0              C1+C20      0.215650     -0.449921
# 1              C1+C20      0.271585      0.000000
# 2              C1+C20      0.260355     -0.283296
# ...

# %%
G=nx.from_pandas_edgelist(data, source='TF_Family', target='Target', edge_attr='PCC_under_C1')

# %%
nx.draw_circular(G)

# %%
net = Network(notebook=True, bgcolor= '#ffffff',neighborhood_highlight=True)

# %%
net.from_nx(G)

# %%
net.show('NAC_hub_C1+C20-slice.html')
# Out:
# NAC_hub_C1+C20-slice.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="NAC_hub_C1+C20-slice.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
net.save_graph('NAC_hub_C1+C20-slice.html')

# %%
def generate_color():
  random_number = random.randint(0,16777215)
  hex_number = str(hex(random_number))
  hex_number ='#'+ hex_number[2:]
  return hex_number
